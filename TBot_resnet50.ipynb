# %%
import logging
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import models, transforms
from PIL import Image

import nest_asyncio  
nest_asyncio.apply()

from telegram import (
    Update,
    InlineKeyboardButton,
    InlineKeyboardMarkup,
)
from telegram.ext import (
    ApplicationBuilder,
    CommandHandler,
    ContextTypes,
    CallbackQueryHandler,
    MessageHandler,
    filters,
)

import os

# ---------------------
# LOGGING
# ---------------------
logging.basicConfig(
    format="%(asctime)s - %(name)s - %(levelname)s - %(message)s", 
    level=logging.INFO
)
logger = logging.getLogger(__name__)

# ---------------------
# GLOBAL VARIABLES
# ---------------------

# Device (CPU/GPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Alphabetical list of 47 texture classes (DTD)
classes = [
    "banded", "blotchy", "braided", "bubbly", "bumpy", 
    "chequered", "cobwebbed", "cracked", "crosshatched", "crystalline",
    "dotted", "fibrous", "flecked", "freckled", "frilly", 
    "gauzy", "grid", "grooved", "honeycombed", "interlaced",
    "knitted", "lacelike", "lined", "marbled", "matted", 
    "meshed", "paisley", "perforated", "pitted", "pleated",
    "polka-dotted", "porous", "potholed", "scaly", "smeared",
    "spiralled", "sprinkled", "stained", "stratified", "striped",
    "studded", "swirly", "veined", "waffled", "woven",
    "wrinkled", "zigzagged"
]
num_classes = len(classes)  

# ---------------------
# MODEL LOADING
# ---------------------
model = models.resnet50(pretrained=True)

# Change the last layer for 47 classes (DTD)
in_features = model.fc.in_features
model.fc = nn.Linear(in_features, num_classes)

# Load trained weights (the file 'resnet50_dtd_split1.pth' must be located nearby)
weights_path = "resnet50_dtd_split1.pth"
if os.path.exists(weights_path):
    model.load_state_dict(torch.load(weights_path, map_location=device))
    logger.info("Model weights loaded successfully.")
else:
    logger.warning(f"Could not find the weights file {weights_path}! Continuing without loading...")

model.to(device)
model.eval()

# ---------------------
# IMAGE PREPROCESSING
# ---------------------
preprocess = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std =[0.229, 0.224, 0.225]),
])

# ---------------------
# HANDLERS
# ---------------------

async def start_command(update: Update, context: ContextTypes.DEFAULT_TYPE):
    """
    Handler for the /start command.
    Greets the user and offers the "screen" button.
    """
    keyboard = [
        [InlineKeyboardButton("screen", callback_data="screen")]
    ]
    reply_markup = InlineKeyboardMarkup(keyboard)

    await update.message.reply_text(
        text=(
            "Hello! I’m a bot for texture recognition.\n\n"
            "Press the button below to send me an image, "
            "and I’ll tell you which texture it is."
        ),
        reply_markup=reply_markup
    )

async def button_callback(update: Update, context: ContextTypes.DEFAULT_TYPE):
    """
    Handler for inline button presses (in particular, the "screen" button).
    """
    query = update.callback_query
    await query.answer()

    if query.data == "screen":
        text_instructions = (
            "Please send me a photo (as a separate message), and I’ll tell you "
            "which texture it is.\n\n"
            "Once you get the result, you can press 'screen' again "
            "if you want to scan another image."
        )
        await query.edit_message_text(text=text_instructions)

async def photo_handler(update: Update, context: ContextTypes.DEFAULT_TYPE):
    """
    Handler for photos (images) sent by the user.
    """
    # Get the photo object (Telegram sends photos in several sizes).
    photo = update.message.photo[-1]  

    # Download the image to a temporary file
    image_path = "temp_image.jpg"
    photo_file = await photo.get_file()
    await photo_file.download_to_drive(image_path)

    # Load with PIL
    image = Image.open(image_path).convert("RGB")
    input_tensor = preprocess(image).unsqueeze(0).to(device)

    with torch.no_grad():
        logits = model(input_tensor)
        probs = F.softmax(logits, dim=1)
        pred_idx = torch.argmax(probs, dim=1).item()
        predicted_class = classes[pred_idx]
        confidence = probs[0, pred_idx].item()

    result_text = (
        f"Predicted class: {predicted_class}\n"
        f"Confidence: {confidence:.2f}"
    )
    await update.message.reply_text(result_text)

    # Offer the "screen" button again
    keyboard = [
        [InlineKeyboardButton("screen", callback_data="screen")]
    ]
    reply_markup = InlineKeyboardMarkup(keyboard)
    await update.message.reply_text(
        text="If you want to recognize another image, press 'screen'.",
        reply_markup=reply_markup
    )

# ---------------------
# MAIN (bot launch)
# ---------------------
if __name__ == "__main__":
    # Connect to Telegram
    TELEGRAM_TOKEN = "YOUR_TELEGRAM_TOKEN"
    application = ApplicationBuilder().token(TELEGRAM_TOKEN).build()

    # Register handlers
    application.add_handler(CommandHandler("start", start_command))
    application.add_handler(CallbackQueryHandler(button_callback))
    application.add_handler(MessageHandler(filters.PHOTO, photo_handler))

    # Run the bot (run_polling is asynchronous internally, but we call it synchronously)
    application.run_polling()
# Out:
# /Users/iliastulov/miniconda3/lib/python3.12/collections/__init__.py:447: RuntimeWarning: coroutine 'main' was never awaited
#   @classmethod
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# /var/folders/b6/kcqg7wpx5_q3ngxl5ff5t3mr0000gn/T/ipykernel_4945/3850466050.py:70: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(weights_path, map_location=device))
# 2024-12-24 01:00:21,523 - __main__ - INFO - Model weights loaded successfully.
# 2024-12-24 01:00:21,967 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getMe "HTTP/1.1 200 OK"
# 2024-12-24 01:00:22,090 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/deleteWebhook "HTTP/1.1 200 OK"
# 2024-12-24 01:00:22,094 - telegram.ext.Application - INFO - Application started
# 2024-12-24 01:00:28,032 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:00:28,657 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/sendMessage "HTTP/1.1 200 OK"
# 2024-12-24 01:00:29,936 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:00:30,083 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/answerCallbackQuery "HTTP/1.1 200 OK"
# 2024-12-24 01:00:30,275 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/editMessageText "HTTP/1.1 200 OK"
# 2024-12-24 01:00:38,671 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:00:39,161 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getFile "HTTP/1.1 200 OK"
# 2024-12-24 01:00:39,292 - httpx - INFO - HTTP Request: GET https://api.telegram.org/file/bot7047736398%3AAAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/photos/file_2.jpg "HTTP/1.1 200 OK"
# 2024-12-24 01:00:39,673 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/sendMessage "HTTP/1.1 200 OK"
# 2024-12-24 01:00:39,781 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/sendMessage "HTTP/1.1 200 OK"
# 2024-12-24 01:00:48,790 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:00:58,901 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:01:09,021 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:01:19,132 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:01:29,240 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:01:39,338 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:01:49,445 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:01:51,014 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:01:51,822 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/sendMessage "HTTP/1.1 200 OK"
# 2024-12-24 01:02:01,149 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:02:11,282 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:02:21,385 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:02:31,501 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:02:41,610 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:02:51,705 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:03:01,834 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:03:07,699 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:03:08,258 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getFile "HTTP/1.1 200 OK"
# 2024-12-24 01:03:08,373 - httpx - INFO - HTTP Request: GET https://api.telegram.org/file/bot7047736398%3AAAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/photos/file_3.jpg "HTTP/1.1 200 OK"
# 2024-12-24 01:03:08,925 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/sendMessage "HTTP/1.1 200 OK"
# 2024-12-24 01:03:09,051 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/sendMessage "HTTP/1.1 200 OK"
# 2024-12-24 01:03:17,819 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:03:27,920 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:03:38,037 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:03:48,137 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:03:58,238 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:04:08,360 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:04:18,466 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:04:28,238 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:04:28,757 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getFile "HTTP/1.1 200 OK"
# 2024-12-24 01:04:28,871 - httpx - INFO - HTTP Request: GET https://api.telegram.org/file/bot7047736398%3AAAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/photos/file_4.jpg "HTTP/1.1 200 OK"
# 2024-12-24 01:04:29,295 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/sendMessage "HTTP/1.1 200 OK"
# 2024-12-24 01:04:29,420 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/sendMessage "HTTP/1.1 200 OK"
# 2024-12-24 01:04:38,325 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:04:48,665 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:04:57,380 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:04:57,773 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/answerCallbackQuery "HTTP/1.1 200 OK"
# 2024-12-24 01:04:57,964 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/editMessageText "HTTP/1.1 200 OK"
# 2024-12-24 01:05:07,512 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:05:17,604 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:05:27,705 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:05:35,083 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:05:35,590 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getFile "HTTP/1.1 200 OK"
# 2024-12-24 01:05:35,709 - httpx - INFO - HTTP Request: GET https://api.telegram.org/file/bot7047736398%3AAAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/photos/file_5.jpg "HTTP/1.1 200 OK"
# 2024-12-24 01:05:35,971 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/sendMessage "HTTP/1.1 200 OK"
# 2024-12-24 01:05:36,074 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/sendMessage "HTTP/1.1 200 OK"
# 2024-12-24 01:05:45,204 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:05:55,300 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:06:05,393 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:06:15,513 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:06:25,602 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:06:35,718 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:06:46,016 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:06:56,136 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:06:56,890 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:06:57,362 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getFile "HTTP/1.1 200 OK"
# 2024-12-24 01:06:57,480 - httpx - INFO - HTTP Request: GET https://api.telegram.org/file/bot7047736398%3AAAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/photos/file_6.jpg "HTTP/1.1 200 OK"
# 2024-12-24 01:06:57,858 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/sendMessage "HTTP/1.1 200 OK"
# 2024-12-24 01:06:57,966 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/sendMessage "HTTP/1.1 200 OK"
# 2024-12-24 01:07:06,988 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:07:17,206 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:07:27,292 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:07:37,409 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:07:47,762 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:07:53,641 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:07:54,132 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getFile "HTTP/1.1 200 OK"
# 2024-12-24 01:07:54,253 - httpx - INFO - HTTP Request: GET https://api.telegram.org/file/bot7047736398%3AAAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/photos/file_7.jpg "HTTP/1.1 200 OK"
# 2024-12-24 01:07:54,685 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/sendMessage "HTTP/1.1 200 OK"
# 2024-12-24 01:07:54,810 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/sendMessage "HTTP/1.1 200 OK"
# 2024-12-24 01:08:03,742 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:08:13,836 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:08:20,116 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:08:20,502 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getFile "HTTP/1.1 200 OK"
# 2024-12-24 01:08:20,644 - httpx - INFO - HTTP Request: GET https://api.telegram.org/file/bot7047736398%3AAAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/photos/file_8.jpg "HTTP/1.1 200 OK"
# 2024-12-24 01:08:20,945 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/sendMessage "HTTP/1.1 200 OK"
# 2024-12-24 01:08:21,089 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/sendMessage "HTTP/1.1 200 OK"
# 2024-12-24 01:08:30,245 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:08:40,343 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:08:50,738 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:08:52,519 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:08:53,004 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/answerCallbackQuery "HTTP/1.1 200 OK"
# 2024-12-24 01:08:53,142 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/editMessageText "HTTP/1.1 200 OK"
# 2024-12-24 01:08:55,070 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:08:55,199 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getFile "HTTP/1.1 200 OK"
# 2024-12-24 01:08:55,333 - httpx - INFO - HTTP Request: GET https://api.telegram.org/file/bot7047736398%3AAAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/photos/file_9.jpg "HTTP/1.1 200 OK"
# 2024-12-24 01:08:55,832 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/sendMessage "HTTP/1.1 200 OK"
# 2024-12-24 01:08:55,961 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/sendMessage "HTTP/1.1 200 OK"
# 2024-12-24 01:09:05,486 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:09:15,713 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:09:19,091 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:09:19,568 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getFile "HTTP/1.1 200 OK"
# 2024-12-24 01:09:19,677 - httpx - INFO - HTTP Request: GET https://api.telegram.org/file/bot7047736398%3AAAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/photos/file_10.jpg "HTTP/1.1 200 OK"
# 2024-12-24 01:09:20,154 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/sendMessage "HTTP/1.1 200 OK"
# 2024-12-24 01:09:20,274 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/sendMessage "HTTP/1.1 200 OK"
# 2024-12-24 01:09:29,200 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:09:39,356 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:09:49,457 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:09:59,566 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:10:09,688 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:10:19,833 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:10:29,930 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:10:40,028 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:10:50,236 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:11:00,566 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:11:10,657 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:11:20,761 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:11:21,814 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:11:22,324 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getFile "HTTP/1.1 200 OK"
# 2024-12-24 01:11:22,457 - httpx - INFO - HTTP Request: GET https://api.telegram.org/file/bot7047736398%3AAAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/photos/file_11.jpg "HTTP/1.1 200 OK"
# 2024-12-24 01:11:22,796 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/sendMessage "HTTP/1.1 200 OK"
# 2024-12-24 01:11:22,914 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/sendMessage "HTTP/1.1 200 OK"
# 2024-12-24 01:11:32,000 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:11:42,090 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:11:52,201 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:11:57,546 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:11:57,946 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getFile "HTTP/1.1 200 OK"
# 2024-12-24 01:11:58,067 - httpx - INFO - HTTP Request: GET https://api.telegram.org/file/bot7047736398%3AAAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/photos/file_12.jpg "HTTP/1.1 200 OK"
# 2024-12-24 01:11:58,348 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/sendMessage "HTTP/1.1 200 OK"
# 2024-12-24 01:11:58,482 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/sendMessage "HTTP/1.1 200 OK"
# 2024-12-24 01:12:07,660 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:12:17,767 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:12:26,702 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:12:27,190 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getFile "HTTP/1.1 200 OK"
# 2024-12-24 01:12:27,326 - httpx - INFO - HTTP Request: GET https://api.telegram.org/file/bot7047736398%3AAAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/photos/file_13.jpg "HTTP/1.1 200 OK"
# 2024-12-24 01:12:27,667 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/sendMessage "HTTP/1.1 200 OK"
# 2024-12-24 01:12:27,796 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/sendMessage "HTTP/1.1 200 OK"
# 2024-12-24 01:12:36,812 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:12:46,904 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:12:56,999 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:13:07,252 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:13:17,632 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:13:27,724 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:13:37,833 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:13:47,946 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:13:58,030 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:14:08,159 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:14:18,268 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:14:28,370 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:14:38,474 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:14:48,626 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:14:58,716 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:15:08,813 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:15:18,922 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:15:29,008 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:15:39,103 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:15:49,220 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:15:59,727 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:16:09,823 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:16:19,923 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:16:30,044 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:16:40,446 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:16:50,549 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:17:00,721 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:17:10,816 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:17:20,918 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:17:31,136 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:17:41,259 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:17:51,355 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:18:01,466 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:18:11,550 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:18:21,820 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:18:31,959 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:18:42,046 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:18:52,141 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:19:02,321 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:19:12,405 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:19:22,511 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:19:32,620 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:19:42,727 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:19:52,813 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:20:02,968 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:20:13,062 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:20:23,153 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:20:33,238 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:20:43,340 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:20:53,434 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:21:03,533 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:21:13,625 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:21:23,721 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:21:33,960 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:21:44,059 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:21:54,171 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:22:04,273 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:22:14,379 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:22:24,507 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:22:34,622 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:22:44,781 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:22:55,230 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:23:05,336 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:23:15,424 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:23:25,525 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:23:35,671 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:23:45,773 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:23:55,872 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:24:06,149 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:24:16,261 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:24:26,387 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:24:36,500 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:24:46,604 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:24:56,691 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:25:06,801 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:25:16,926 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:25:27,041 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:25:37,178 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:25:47,295 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:25:57,401 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:26:07,843 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:26:17,953 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:26:28,083 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:26:38,207 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:26:48,322 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:26:58,419 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:27:08,516 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:27:18,637 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:27:28,756 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:27:38,858 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:27:48,992 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:27:59,107 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:28:09,211 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:28:19,341 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:28:29,440 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:28:39,548 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:28:49,775 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:28:59,911 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:29:10,009 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:29:20,184 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:29:30,297 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:29:40,406 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:29:50,625 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:30:00,743 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:30:10,828 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:30:21,008 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:30:31,149 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:30:41,253 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:30:51,348 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:31:01,446 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:31:11,544 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:31:21,628 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:31:31,722 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:31:41,846 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:31:51,937 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:32:02,081 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:32:12,216 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:32:22,332 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:32:32,490 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:32:42,589 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:32:53,095 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:33:03,210 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:33:13,323 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:33:23,418 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:33:33,504 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:33:43,736 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:33:53,902 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:34:04,000 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:34:14,174 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:34:24,313 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:34:34,464 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:34:44,593 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:34:54,687 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:35:04,864 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:35:14,983 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:35:25,138 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:35:35,242 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:35:45,330 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:35:55,553 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:36:05,657 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:36:15,759 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:36:25,864 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:36:35,956 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:36:46,050 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:36:56,146 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:37:06,225 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:37:16,327 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:37:26,464 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:37:36,620 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:37:46,736 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:37:56,835 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:38:06,964 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:38:17,075 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:38:27,187 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:38:37,371 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:38:47,492 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:38:57,590 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:39:07,731 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:39:17,827 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:39:27,918 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:39:38,020 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:39:48,127 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:39:58,229 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:40:08,329 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:40:18,425 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:40:28,653 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:40:38,839 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:40:48,940 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:40:59,024 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:41:09,202 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:41:19,431 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:41:29,535 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:41:39,649 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:41:50,057 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:42:00,509 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:42:08,932 - httpx - INFO - HTTP Request: POST https://api.telegram.org/bot7047736398:AAH8H_ykDiQDhoERs6F8hb8yDci_U7LdXcU/getUpdates "HTTP/1.1 200 OK"
# 2024-12-24 01:42:08,935 - telegram.ext.Application - INFO - Application is stopping. This might take a moment.
# 2024-12-24 01:42:08,938 - telegram.ext.Application - INFO - Application.stop() complete
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 180
#     177 application.add_handler(MessageHandler(filters.PHOTO, photo_handler))
#     179 # Run the bot (run_polling is asynchronous internally, but we call it synchronously)
# --> 180 application.run_polling()
#
# File ~/miniconda3/lib/python3.12/site-packages/telegram/ext/_application.py:881, in Application.run_polling(self, poll_interval, timeout, bootstrap_retries, read_timeout, write_timeout, connect_timeout, pool_timeout, allowed_updates, drop_pending_updates, close_loop, stop_signals)
#     878 def error_callback(exc: TelegramError) -> None:
#     879     self.create_task(self.process_error(error=exc, update=None))
# --> 881 return self.__run(
#     882     updater_coroutine=self.updater.start_polling(
#     883         poll_interval=poll_interval,
#     884         timeout=timeout,
#     885         bootstrap_retries=bootstrap_retries,
#     886         read_timeout=read_timeout,
#     887         write_timeout=write_timeout,
#     888         connect_timeout=connect_timeout,
#     889         pool_timeout=pool_timeout,
#     890         allowed_updates=allowed_updates,
#     891         drop_pending_updates=drop_pending_updates,
#     892         error_callback=error_callback,  # if there is an error in fetching updates
#     893     ),
#     894     close_loop=close_loop,
#     895     stop_signals=stop_signals,
#     896 )
#
# File ~/miniconda3/lib/python3.12/site-packages/telegram/ext/_application.py:1109, in Application.__run(self, updater_coroutine, stop_signals, close_loop)
#    1107 finally:
#    1108     if close_loop:
# -> 1109         loop.close()
#
# File ~/miniconda3/lib/python3.12/asyncio/unix_events.py:68, in _UnixSelectorEventLoop.close(self)
#      67 def close(self):
# ---> 68     super().close()
#      69     if not sys.is_finalizing():
#      70         for sig in list(self._signal_handlers):
#
# File ~/miniconda3/lib/python3.12/asyncio/selector_events.py:101, in BaseSelectorEventLoop.close(self)
#      99 def close(self):
#     100     if self.is_running():
# --> 101         raise RuntimeError("Cannot close a running event loop")
#     102     if self.is_closed():
#     103         return
#
# RuntimeError: Cannot close a running event loop
